# %%
import numpy as np
import xarray as xr

# %%
ds = xr.open_dataset("../data/example.nc")

# %%
ds
# Out:
# <xarray.Dataset> Size: 18kB
# Dimensions:            (n_members: 1, x_size: 34, y_size_coupled: 68,
#                         x_size_sigma: 65, y_size_sigma: 33,
#                         function_scaling_size: 18)
# Dimensions without coordinates: n_members, x_size, y_size_coupled,
#                                 x_size_sigma, y_size_sigma,
#                                 function_scaling_size
# Data variables:
#     initial_data       (n_members, x_size, y_size_coupled) float32 9kB ...
#     sigma_values       (n_members, x_size_sigma, y_size_sigma) float32 9kB ...
#     function_scalings  (n_members, function_scaling_size) float32 72B ...
#     Du                 float32 4B ...
#     Dv                 float32 4B ...
# Attributes: (12/14)
#     type_of_equation:        2
#     n_members:               1
#     x_size:                  32
#     x_length:                32.0
#     y_size:                  32
#     y_length:                32.0
#     ...                      ...
# ...

# %%
ds.attrs["number_timesteps"] = 200_000

# %%
# write ds to a new file
ds.to_netcdf("../data/example_long.nc", mode="w")
